# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## basic plotting in the seaborn
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title('scatter plot')
plt.show()

# %%
sns.lineplot(y='total_bill',x='size',data=tips)
plt.title('line plot')
plt.show()

# %%
# Categorical plots
sns.barplot(x='day',y='total_bill',data=tips)
plt.title('Bar plot')
plt.show()

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
plt.show()

# %%
## histograms
sns.histplot(tips['total_bill'],kde=True)
plt.show()

# %%
## kde plot
sns.kdeplot(tips['total_bill'],fill=True)
plt.show()

# %%
sns.pairplot(data=tips)

# %%
corr=tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(annot=True,data=corr)
plt.show()

# %%
sales_df=pd.read_csv("100 Sales Records.csv")

# %%
sales_df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Country',y='Total Profit',data=sales_df,estimator=sum)
plt.show()
